# %% [markdown]
# # Imports

# %%
# Panda imports
import pandas as pd

# %% [markdown]
# # File location

# %%
UHS_FILE_PATH = "question_files/UHS__2012.xlsx"

# %% [markdown]
# # Data overview

# %%
df = pd.read_excel(UHS_FILE_PATH)

df.head(20)
# Out:
#                          A                    B                       C  \
# 0                   I only              II only                  I only
# 1          M = -91 x 10 kg  M = 1.6027 x 10⁷ kg       M = 5.98 x 10³ kg
# 2   Water or hydral energy    Geothermal energy      Fossil fuel energy
# 3                  21001 J              21000 J                210000 J
# 4                 4 x 10 J             0.0002 J              0.000001 J
# 5                     Mole               Ampere                  Kelvin
# 6           712​​(2i+3j−k)       127​(4i+2j−2k)          7/12​(4i+2j+k)
# 7               3i+6j−2k/7       3i/7+6j/7−2k/7          3i/7+6j/7+2k/7
# 8         Average velocity     Uniform velocity  Instantaneous velocity
# 9                    196 m                  2 m                     ½ m
# 10                 98/2​ m                9.8 m                    49 m
# 11                    360°                 180°                    100°
# ...

# %%
for index, row in df.iterrows():
    print(
        f"Index: {index}",
        f"\nSubject: {row['Topical_Heading']}"
        f"\nTopic: {row['Topical_Subheading']}",
        f"\nQuestion {row['Question Number']}: {row['Questions']}",
        f"\nOption A: {row['A']}",
        f"\nOption B: {row['B']}",
        f"\nOption C: {row['C']}",
        f"\nOption D: {row['D']}",
        f"\nOption E: {row['E']}",
        f"\nCorrect Option: {row[row['Answers']]}"
        "\n"
    )
# Out:
# Index: 0
# Subject: Chemistry
# Topic: Topic 1
# Question 1: Identify the example/s of Static Equilibrium: I. A book lying on a horizontal table
# II. A building
# III. A bridge
# Option A: I only
# Option B: II only
# Option C: I only
# Option D: II and III only
# Option E: I, II, and III
# Correct Option: I only
#
# Index: 1
# Subject: Biology
# Topic: Topic 1
# Question 2: The mass of earth on the basis of Newton's Law of Gravitation is given by:
# Option A: M = -91 x 10 kg
# Option B: M = 1.6027 x 10⁷ kg
# Option C: M = 5.98 x 10³ kg
# Option D: M = 6.02 x 10²³ kg
# Option E: M = 3 x 10⁴ kg
# Correct Option: M = 1.6027 x 10⁷ kg
#
# Index: 2
# Subject: Biology
# Topic: Topic 2
# Question 3: Fusion and fission reactions are associated with:
# Option A: Water or hydral energy
# Option B: Geothermal energy
# Option C: Fossil fuel energy
# Option D: Nuclear energy
# Option E: Tidal energy
# Correct Option: Water or hydral energy
#
# Index: 3
# Subject: Physics
# Topic: Topic 1
# ...
